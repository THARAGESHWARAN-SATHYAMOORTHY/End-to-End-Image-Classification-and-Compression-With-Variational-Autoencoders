# %%
# !pip install tensorflow
# !pip install keras
# !pip install python=opencv
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.13.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (66.1.1)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.3.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-macos==2.13.0->tensorflow)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.2)
# Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-sql-connector 2.9.5 requires sqlalchemy<2.0.0,>=1.3.24, but you have sqlalchemy 2.0.29 which is incompatible.
# sqlalchemy 2.0.29 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# sqlalchemy-bigquery 1.10.0 requires sqlalchemy<2.0.0dev,>=1.2.0, but you have sqlalchemy 2.0.29 which is incompatible.
# Successfully installed typing-extensions-4.5.0
# Requirement already satisfied: keras in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.13.1)
# ERROR: Invalid requirement: 'python=opencv'
# Hint: = is not a valid operator. Did you mean == ?
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.24.3)

# %% [markdown]
# Download the dataset from here:
# https://drive.google.com/file/d/1lUmzcMUFJSF60DFMK5yKQClGqg9v8fcP/view?usp=sharing
# And extract it into your working directory

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

import os
import numpy as np

# %%
image_dir = "/Users/tharageshwaransathyamoorthy/Documents/anime faces/cropped/"
images = [os.path.join(image_dir, image) for image in os.listdir(image_dir)]
images[:2]
# Out:
# ['/Users/tharageshwaransathyamoorthy/Documents/anime faces/cropped/38921_2012.jpg',
#  '/Users/tharageshwaransathyamoorthy/Documents/anime faces/cropped/56274_2017.jpg']

# %%
# preprocess
image_size = 64

def preprocess(image):
    image = tf.io.read_file(image)
    image = tf.io.decode_jpeg(image)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image = image / 255.0
    image = tf.reshape(image, shape = (image_size, image_size, 3,))
    return image

# %%
batch_size = 128

training_dataset = tf.data.Dataset.from_tensor_slices((images))
training_dataset = training_dataset.map(preprocess)
training_dataset = training_dataset.shuffle(1000).batch(batch_size)

# %%
len(training_dataset)
# Out:
# 241

# %%
# visualize some of them
fig, axes = plt.subplots(5,5, figsize = (14,14))
sample = training_dataset.unbatch().take(25)
sample = [image for image in sample]

idx = 0
for row in range(5):
    for column in range(5):
        axes[row, column].imshow(sample[idx])
        idx+=1

# %%
# build the model

latent_dim = 512

# %%
# !pip install keras
from keras.models import Sequential, Model

from keras.layers import Dense, Conv2D, Conv2DTranspose, Input, Flatten, BatchNormalization, Lambda, Reshape, Activation
from keras.layers import LeakyReLU
from keras.activations import selu
from keras.layers import Multiply, Add
from keras.optimizers import Adam

from keras import backend as K
# Out:
# Requirement already satisfied: keras in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.13.1)

# %%
K.clear_session()

# %%
encoder_input = Input(shape = (64,64,3))

x = Conv2D(32, kernel_size=5, activation = LeakyReLU(0.02), strides = 1, padding = 'same')(encoder_input)
x = BatchNormalization()(x)

filter_size = [64,128,256,512]
for i in filter_size:
    x = Conv2D(i, kernel_size=5, activation = LeakyReLU(0.02), strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)

x = Flatten()(x)
x = Dense(1024, activation = selu)(x)
encoder_output = BatchNormalization()(x)

# sampling layer
mu = Dense(latent_dim)(encoder_output)
log_var = Dense(latent_dim)(encoder_output)

epsilon = K.random_normal(shape = (tf.shape(mu)[0], tf.shape(mu)[1]))
sigma = tf.exp(0.5 * log_var)

z_eps = Multiply()([sigma, epsilon])
z = Add()([mu, z_eps])

encoder = Model(encoder_input, outputs = [mu, log_var, z], name = 'encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 32)           2432      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 64, 64, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)           51264     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)          204928    ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 16, 16, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)            819456    ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)            1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 512)            3277312   ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 4, 4, 512)            2048      ['conv2d_4[0][0]']
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)                 0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dense (Dense)               (None, 1024)                 8389632   ['flatten[0][0]']
#
#  batch_normalization_5 (Bat  (None, 1024)                 4096      ['dense[0][0]']
#  chNormalization)
#
#  dense_1 (Dense)             (None, 512)                  524800    ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 512)                  524800    ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  tf.compat.v1.shape (TFOpLa  (2,)                         0         ['dense_1[0][0]']
#  mbda)
#
#  tf.compat.v1.shape_1 (TFOp  (2,)                         0         ['dense_1[0][0]']
#  Lambda)
#
#  tf.math.multiply (TFOpLamb  (None, 512)                  0         ['dense_2[0][0]']
#  da)
#
#  tf.__operators__.getitem (  ()                           0         ['tf.compat.v1.shape[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  ()                           0         ['tf.compat.v1.shape_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.math.exp (TFOpLambda)    (None, 512)                  0         ['tf.math.multiply[0][0]']
#
#  tf.random.normal (TFOpLamb  (None, 512)                  0         ['tf.__operators__.getitem[0][
#  da)                                                                0]',
#                                                                      'tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  multiply (Multiply)         (None, 512)                  0         ['tf.math.exp[0][0]',
#                                                                      'tf.random.normal[0][0]']
#
#  add (Add)                   (None, 512)                  0         ['dense_1[0][0]',
#                                                                      'multiply[0][0]']
#
# ==================================================================================================
# Total params: 13802688 (52.65 MB)
# Trainable params: 13798656 (52.64 MB)
# Non-trainable params: 4032 (15.75 KB)
# __________________________________________________________________________________________________

# %%
# build the decoder

decoder = Sequential()
decoder.add(Dense(1024, activation = selu, input_shape = (latent_dim, )))
decoder.add(BatchNormalization())

decoder.add(Dense(8192, activation = selu))
decoder.add(Reshape((4,4,512)))

decoder.add(Conv2DTranspose(256, (5,5), activation = LeakyReLU(0.02), strides = 2, padding = 'same'))
decoder.add(BatchNormalization())

decoder.add(Conv2DTranspose(128, (5,5), activation = LeakyReLU(0.02), strides = 2, padding = 'same'))
decoder.add(BatchNormalization())

decoder.add(Conv2DTranspose(64, (5,5), activation = LeakyReLU(0.02), strides = 2, padding = 'same'))
decoder.add(BatchNormalization())

decoder.add(Conv2DTranspose(32, (5,5), activation = LeakyReLU(0.02), strides = 2, padding = 'same'))
decoder.add(BatchNormalization())

decoder.add(Conv2DTranspose(3, (5,5), activation = "sigmoid", strides = 1, padding = 'same'))
decoder.add(BatchNormalization())

decoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1024)              525312
#
#  batch_normalization_6 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_4 (Dense)             (None, 8192)              8396800
#
#  reshape (Reshape)           (None, 4, 4, 512)         0
#
#  conv2d_transpose (Conv2DTr  (None, 8, 8, 256)         3277056
#  anspose)
#
#  batch_normalization_7 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_transpose_1 (Conv2D  (None, 16, 16, 128)       819328
#  Transpose)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_transpose_2 (Conv2D  (None, 32, 32, 64)        204864
#  Transpose)
#
#  batch_normalization_9 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  conv2d_transpose_3 (Conv2D  (None, 64, 64, 32)        51232
#  Transpose)
#
#  batch_normalization_10 (Ba  (None, 64, 64, 32)        128
#  tchNormalization)
#
#  conv2d_transpose_4 (Conv2D  (None, 64, 64, 3)         2403
#  Transpose)
#
#  batch_normalization_11 (Ba  (None, 64, 64, 3)         12
#  tchNormalization)
#
# =================================================================
# Total params: 13283023 (50.67 MB)
# Trainable params: 13280009 (50.66 MB)
# Non-trainable params: 3014 (11.77 KB)
# _________________________________________________________________

# %%
# make loss function 
# vae loss = reconstruction loss + KL div

def reconstruction_loss(y, y_pred):
    return tf.reduce_mean(tf.square(y - y_pred))

def kl_loss(mu, log_var):
    loss = -0.5 * tf.reduce_mean(1 + log_var - tf.square(mu) - tf.exp(log_var))
    return loss

def vae_loss(y_true, y_pred, mu, log_var):
    return reconstruction_loss(y_true, y_pred) + (1 / (64*64)) * kl_loss(mu, log_var)

# %%
# conbine encoder and decoder
mu, log_var, z = encoder(encoder_input)
reconstructed = decoder(z)
model = Model(encoder_input, reconstructed, name ="vae")
loss = kl_loss(mu, log_var)
model.add_loss(loss)
model.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  encoder (Functional)        [(None, 512),                1380268   ['input_1[0][0]']
#                               (None, 512),                8
#                               (None, 512)]
#
#  sequential (Sequential)     (None, 64, 64, 3)            1328302   ['encoder[0][2]']
#                                                           3
#
#  tf.__operators__.add (TFOp  (None, 512)                  0         ['encoder[0][1]']
#  Lambda)
#
#  tf.math.square (TFOpLambda  (None, 512)                  0         ['encoder[0][0]']
#  )
#
#  tf.math.subtract (TFOpLamb  (None, 512)                  0         ['tf.__operators__.add[0][0]',
#  da)                                                                 'tf.math.square[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)  (None, 512)                  0         ['encoder[0][1]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 512)                  0         ['tf.math.subtract[0][0]',
#  mbda)                                                               'tf.math.exp_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.math.subtract_1[0][0]']
#  ambda)
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_mean[0][0]']
#  mbda)
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.multiply_1[0][0]']
#
# ==================================================================================================
# Total params: 27085711 (103.32 MB)
# Trainable params: 27078665 (103.30 MB)
# Non-trainable params: 7046 (27.52 KB)
# __________________________________________________________________________________________________

# %%
# make a function to save images while learning
def save_images(model, epoch, step, input_):
    prediction = model.predict(input_)
    fig, axes = plt.subplots(5,5, figsize = (14,14))
    idx = 0
    for row in range(5):
        for column in range(5):
            image = prediction[idx] * 255
            image = image.astype("int32")
            axes[row, column].imshow(image)
            axes[row, column].axis("off")
            idx+=1
    output_path = "output/"
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    plt.savefig(output_path + "Epoch_{:04d}_step_{:04d}.jpg".format(epoch, step))
    plt.close()

# %%
# train vae

from keras.optimizers import Adam

random_vector = tf.random.normal(shape = (25, latent_dim,))
save_images(decoder, 0, 0, random_vector)

mse_losses = []
kl_losses = []

optimizer = Adam(0.0001, 0.5)
epochs = 100

for epoch in range(1, epochs + 1):
    print("Epoch: ", epoch)
    for step, training_batch in enumerate(training_dataset):
        with tf.GradientTape() as tape:
            reconstructed = model(training_batch)
            y_true = tf.reshape(training_batch, shape = [-1])
            y_pred = tf.reshape(reconstructed, shape = [-1])
            
            mse_loss = reconstruction_loss(y_true, y_pred)
            mse_losses.append(mse_loss.numpy())
            
            kl = sum(model.losses)
            kl_losses.append(kl.numpy())
            
            train_loss = 0.01 * kl + mse_loss
            
            grads = tape.gradient(train_loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            
            if step % 10 == 0:
                save_images(decoder, epoch, step, random_vector)
            print("Epoch: %s - Step: %s - MSE loss: %s - KL loss: %s" % (epoch, step, mse_loss.numpy(), kl.numpy()))
# Out:
# 1/1 [==============================] - 0s 150ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch:  1
# 1/1 [==============================] - 0s 78ms/step
# Epoch: 1 - Step: 0 - MSE loss: 0.094292015 - KL loss: 0.00056840235
# Epoch: 1 - Step: 1 - MSE loss: 0.09559538 - KL loss: 0.00048677908
# Epoch: 1 - Step: 2 - MSE loss: 0.09290045 - KL loss: 0.00039576978
# Epoch: 1 - Step: 3 - MSE loss: 0.098276876 - KL loss: 0.0003416153
# Epoch: 1 - Step: 4 - MSE loss: 0.09517459 - KL loss: 0.00026683562
# Epoch: 1 - Step: 5 - MSE loss: 0.097020596 - KL loss: 0.00022505457
# Epoch: 1 - Step: 6 - MSE loss: 0.098078854 - KL loss: 0.00019586291
# Epoch: 1 - Step: 7 - MSE loss: 0.09682437 - KL loss: 0.0001583757
# Epoch: 1 - Step: 8 - MSE loss: 0.09669495 - KL loss: 0.00014150736
# Epoch: 1 - Step: 9 - MSE loss: 0.09356382 - KL loss: 0.00012536673
# 1/1 [==============================] - 0s 76ms/step
# Epoch: 1 - Step: 10 - MSE loss: 0.09268302 - KL loss: 0.00012335743
# Epoch: 1 - Step: 11 - MSE loss: 0.09149402 - KL loss: 0.00013459098
# Epoch: 1 - Step: 12 - MSE loss: 0.09044062 - KL loss: 0.0001676577
# Epoch: 1 - Step: 13 - MSE loss: 0.08786661 - KL loss: 0.00024778928
# Epoch: 1 - Step: 14 - MSE loss: 0.08469009 - KL loss: 0.00047417142
# Epoch: 1 - Step: 15 - MSE loss: 0.08637556 - KL loss: 0.0011519622
# Epoch: 1 - Step: 16 - MSE loss: 0.08181294 - KL loss: 0.003612769
# Epoch: 1 - Step: 17 - MSE loss: 0.07915346 - KL loss: 0.014112614
# Epoch: 1 - Step: 18 - MSE loss: 0.08234656 - KL loss: 0.049507044
# Epoch: 1 - Step: 19 - MSE loss: 0.07679071 - KL loss: 0.029121092
# 1/1 [==============================] - 0s 72ms/step
# Epoch: 1 - Step: 20 - MSE loss: 0.07777469 - KL loss: 0.10101572
# Epoch: 1 - Step: 21 - MSE loss: 0.07252639 - KL loss: 0.16671409
# Epoch: 1 - Step: 22 - MSE loss: 0.075334035 - KL loss: 0.054062676
# Epoch: 1 - Step: 23 - MSE loss: 0.07015667 - KL loss: 0.12986863
# Epoch: 1 - Step: 24 - MSE loss: 0.06849718 - KL loss: 0.08976924
# Epoch: 1 - Step: 25 - MSE loss: 0.07256628 - KL loss: 0.07482683
# Epoch: 1 - Step: 26 - MSE loss: 0.06955958 - KL loss: 0.09871894
# Epoch: 1 - Step: 27 - MSE loss: 0.067354396 - KL loss: 0.13820596
# Epoch: 1 - Step: 28 - MSE loss: 0.072539546 - KL loss: 0.0473705
# Epoch: 1 - Step: 29 - MSE loss: 0.073451154 - KL loss: 0.12209201
# 1/1 [==============================] - 0s 90ms/step
# Epoch: 1 - Step: 30 - MSE loss: 0.06901469 - KL loss: 0.057679944
# Epoch: 1 - Step: 31 - MSE loss: 0.06876864 - KL loss: 0.09423977
# Epoch: 1 - Step: 32 - MSE loss: 0.06523692 - KL loss: 0.1012638
# Epoch: 1 - Step: 33 - MSE loss: 0.06681036 - KL loss: 0.0666869
# Epoch: 1 - Step: 34 - MSE loss: 0.06594937 - KL loss: 0.07350532
# Epoch: 1 - Step: 35 - MSE loss: 0.062750116 - KL loss: 0.09354819
# Epoch: 1 - Step: 36 - MSE loss: 0.064347304 - KL loss: 0.11687177
# Epoch: 1 - Step: 37 - MSE loss: 0.079470545 - KL loss: 0.09159538
# Epoch: 1 - Step: 38 - MSE loss: 0.062248897 - KL loss: 0.10258268
# Epoch: 1 - Step: 39 - MSE loss: 0.0648954 - KL loss: 0.0816806
# 1/1 [==============================] - 0s 67ms/step
# Epoch: 1 - Step: 40 - MSE loss: 0.06557001 - KL loss: 0.033615492
# Epoch: 1 - Step: 41 - MSE loss: 0.0625347 - KL loss: 0.10355741
# Epoch: 1 - Step: 42 - MSE loss: 0.05878793 - KL loss: 0.09748998
# Epoch: 1 - Step: 43 - MSE loss: 0.05901465 - KL loss: 0.09406566
# Epoch: 1 - Step: 44 - MSE loss: 0.06893178 - KL loss: 0.08785832
# Epoch: 1 - Step: 45 - MSE loss: 0.060901996 - KL loss: 0.08486376
# Epoch: 1 - Step: 46 - MSE loss: 0.060517777 - KL loss: 0.09204878
# Epoch: 1 - Step: 47 - MSE loss: 0.062293548 - KL loss: 0.043868996
# Epoch: 1 - Step: 48 - MSE loss: 0.05727918 - KL loss: 0.06989743
# Epoch: 1 - Step: 49 - MSE loss: 0.059961546 - KL loss: 0.10924898
# 1/1 [==============================] - 0s 84ms/step
# Epoch: 1 - Step: 50 - MSE loss: 0.057826012 - KL loss: 0.06278496
# Epoch: 1 - Step: 51 - MSE loss: 0.055177927 - KL loss: 0.0742455
# Epoch: 1 - Step: 52 - MSE loss: 0.060243513 - KL loss: 0.09439224
# Epoch: 1 - Step: 53 - MSE loss: 0.059420228 - KL loss: 0.06812535
# Epoch: 1 - Step: 54 - MSE loss: 0.055994015 - KL loss: 0.07450597
# Epoch: 1 - Step: 55 - MSE loss: 0.059997033 - KL loss: 0.08933711
# Epoch: 1 - Step: 56 - MSE loss: 0.05767061 - KL loss: 0.061568804
# Epoch: 1 - Step: 57 - MSE loss: 0.05625991 - KL loss: 0.0774172
# Epoch: 1 - Step: 58 - MSE loss: 0.054764092 - KL loss: 0.08529468
# Epoch: 1 - Step: 59 - MSE loss: 0.054926116 - KL loss: 0.0685751
# 1/1 [==============================] - 0s 69ms/step
# Epoch: 1 - Step: 60 - MSE loss: 0.05477485 - KL loss: 0.065929905
# Epoch: 1 - Step: 61 - MSE loss: 0.058229182 - KL loss: 0.06961128
# Epoch: 1 - Step: 62 - MSE loss: 0.054665133 - KL loss: 0.071221836
# Epoch: 1 - Step: 63 - MSE loss: 0.05829839 - KL loss: 0.06239023
# Epoch: 1 - Step: 64 - MSE loss: 0.057428468 - KL loss: 0.07806897
# Epoch: 1 - Step: 65 - MSE loss: 0.05530845 - KL loss: 0.07066204
# Epoch: 1 - Step: 66 - MSE loss: 0.056029025 - KL loss: 0.0778116
# Epoch: 1 - Step: 67 - MSE loss: 0.055068716 - KL loss: 0.07954058
# Epoch: 1 - Step: 68 - MSE loss: 0.053205345 - KL loss: 0.07488528
# Epoch: 1 - Step: 69 - MSE loss: 0.05529818 - KL loss: 0.070650876
# 1/1 [==============================] - 0s 70ms/step
# Epoch: 1 - Step: 70 - MSE loss: 0.05461672 - KL loss: 0.078186296
# Epoch: 1 - Step: 71 - MSE loss: 0.05336779 - KL loss: 0.07999483
# Epoch: 1 - Step: 72 - MSE loss: 0.053971756 - KL loss: 0.06818721
# Epoch: 1 - Step: 73 - MSE loss: 0.052348513 - KL loss: 0.07422016
# Epoch: 1 - Step: 74 - MSE loss: 0.055767 - KL loss: 0.072960466
# Epoch: 1 - Step: 75 - MSE loss: 0.056544404 - KL loss: 0.07166098
# Epoch: 1 - Step: 76 - MSE loss: 0.051735055 - KL loss: 0.09546915
# Epoch: 1 - Step: 77 - MSE loss: 0.054985598 - KL loss: 0.067362696
# Epoch: 1 - Step: 78 - MSE loss: 0.05433854 - KL loss: 0.08949458
# Epoch: 1 - Step: 79 - MSE loss: 0.05354081 - KL loss: 0.07222889
# 1/1 [==============================] - 0s 71ms/step
# Epoch: 1 - Step: 80 - MSE loss: 0.05340792 - KL loss: 0.077936016
# Epoch: 1 - Step: 81 - MSE loss: 0.053301696 - KL loss: 0.06487205
# Epoch: 1 - Step: 82 - MSE loss: 0.0486988 - KL loss: 0.08665992
# Epoch: 1 - Step: 83 - MSE loss: 0.052784298 - KL loss: 0.0971764
# Epoch: 1 - Step: 84 - MSE loss: 0.05092414 - KL loss: 0.09251575
# Epoch: 1 - Step: 85 - MSE loss: 0.051890347 - KL loss: 0.09825761
# Epoch: 1 - Step: 86 - MSE loss: 0.051607102 - KL loss: 0.09512467
# Epoch: 1 - Step: 87 - MSE loss: 0.052014917 - KL loss: 0.09095056
# Epoch: 1 - Step: 88 - MSE loss: 0.05221572 - KL loss: 0.05362282
# Epoch: 1 - Step: 89 - MSE loss: 0.049656134 - KL loss: 0.100998506
# 1/1 [==============================] - 0s 68ms/step
# Epoch: 1 - Step: 90 - MSE loss: 0.04959242 - KL loss: 0.12094277
# Epoch: 1 - Step: 91 - MSE loss: 0.047088876 - KL loss: 0.0829438
# Epoch: 1 - Step: 92 - MSE loss: 0.047049735 - KL loss: 0.08825272
# Epoch: 1 - Step: 93 - MSE loss: 0.04900508 - KL loss: 0.09141165
# Epoch: 1 - Step: 94 - MSE loss: 0.04579708 - KL loss: 0.10253375
# Epoch: 1 - Step: 95 - MSE loss: 0.044743907 - KL loss: 0.09102251
# Epoch: 1 - Step: 96 - MSE loss: 0.045747787 - KL loss: 0.090563476
# Epoch: 1 - Step: 97 - MSE loss: 0.049245417 - KL loss: 0.07806946
# Epoch: 1 - Step: 98 - MSE loss: 0.049140498 - KL loss: 0.07592659
# Epoch: 1 - Step: 99 - MSE loss: 0.046360046 - KL loss: 0.09059515
# 1/1 [==============================] - 0s 71ms/step
# Epoch: 1 - Step: 100 - MSE loss: 0.04530233 - KL loss: 0.08706738
# Epoch: 1 - Step: 101 - MSE loss: 0.048094947 - KL loss: 0.08781172
# Epoch: 1 - Step: 102 - MSE loss: 0.046488766 - KL loss: 0.07063949
# Epoch: 1 - Step: 103 - MSE loss: 0.04622136 - KL loss: 0.09584079
# Epoch: 1 - Step: 104 - MSE loss: 0.04852129 - KL loss: 0.08129147
# Epoch: 1 - Step: 105 - MSE loss: 0.047553066 - KL loss: 0.07712922
# Epoch: 1 - Step: 106 - MSE loss: 0.045892533 - KL loss: 0.076582134
# Epoch: 1 - Step: 107 - MSE loss: 0.04822884 - KL loss: 0.09115257
# Epoch: 1 - Step: 108 - MSE loss: 0.047757033 - KL loss: 0.088376015
# Epoch: 1 - Step: 109 - MSE loss: 0.04693331 - KL loss: 0.08195022
# 1/1 [==============================] - 0s 67ms/step
# Epoch: 1 - Step: 110 - MSE loss: 0.04925397 - KL loss: 0.09319699
# Epoch: 1 - Step: 111 - MSE loss: 0.04716997 - KL loss: 0.07164731
# Epoch: 1 - Step: 112 - MSE loss: 0.050144713 - KL loss: 0.0873723
# Epoch: 1 - Step: 113 - MSE loss: 0.04630633 - KL loss: 0.08408347
# Epoch: 1 - Step: 114 - MSE loss: 0.045195397 - KL loss: 0.09155657
# Epoch: 1 - Step: 115 - MSE loss: 0.04520544 - KL loss: 0.090805665
# Epoch: 1 - Step: 116 - MSE loss: 0.04556143 - KL loss: 0.08168845
# Epoch: 1 - Step: 117 - MSE loss: 0.045404732 - KL loss: 0.09164883
# Epoch: 1 - Step: 118 - MSE loss: 0.04343784 - KL loss: 0.0847345
# Epoch: 1 - Step: 119 - MSE loss: 0.04484515 - KL loss: 0.09126948
# 1/1 [==============================] - 0s 74ms/step
# Epoch: 1 - Step: 120 - MSE loss: 0.047198277 - KL loss: 0.101005495
# Epoch: 1 - Step: 121 - MSE loss: 0.044442263 - KL loss: 0.08640654
# Epoch: 1 - Step: 122 - MSE loss: 0.045668494 - KL loss: 0.095121354
# Epoch: 1 - Step: 123 - MSE loss: 0.043406423 - KL loss: 0.081671655
# Epoch: 1 - Step: 124 - MSE loss: 0.046681598 - KL loss: 0.08553641
# Epoch: 1 - Step: 125 - MSE loss: 0.045120448 - KL loss: 0.096134886
# Epoch: 1 - Step: 126 - MSE loss: 0.045990516 - KL loss: 0.08138502
# Epoch: 1 - Step: 127 - MSE loss: 0.046734158 - KL loss: 0.09089051
# Epoch: 1 - Step: 128 - MSE loss: 0.046142116 - KL loss: 0.08633016
# Epoch: 1 - Step: 129 - MSE loss: 0.044231534 - KL loss: 0.10514979
# 1/1 [==============================] - 0s 67ms/step
# Epoch: 1 - Step: 130 - MSE loss: 0.04613718 - KL loss: 0.07420686
# Epoch: 1 - Step: 131 - MSE loss: 0.04563069 - KL loss: 0.096529394
# Epoch: 1 - Step: 132 - MSE loss: 0.04386427 - KL loss: 0.089439385
# Epoch: 1 - Step: 133 - MSE loss: 0.04390948 - KL loss: 0.09774268
# Epoch: 1 - Step: 134 - MSE loss: 0.0452332 - KL loss: 0.09448275
# Epoch: 1 - Step: 135 - MSE loss: 0.04695511 - KL loss: 0.08842575

# %%
# visualize output

import cv2
output_dir = "/Users/tharageshwaransathyamoorthy/Documents/Output/"
files = os.listdir(output_dir)

for file in files:
    image = cv2.imread(output_dir + file)
    cv2.imshow("Output", image)
    if cv2.waitKey(1) and 0xFF == ord('q'):
        break
